# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a54098-boop/ML-LAB/blob/main/ML6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/gender_submission.csv')

# %%
df
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
import numpy as np

# %%
x=np.array(x).reshape(-1,1)
y=np.array(y).ravel()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test =train_test_split(
    x,y,test_size=0.2,random_state=42
)
print(x_train.shape)
print(x_test.shape)
# Out:
# (334, 1)
# (84, 1)

# %%
from sklearn.svm import SVC

# %%
svm_linear=SVC(kernel='linear',class_weight='balanced')
svm_linear.fit(x_train,y_train)
# Out:
# SVC(class_weight='balanced', kernel='linear')

# %%
y_pred=svm_linear.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score,f1_score

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.5238095238095238

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred,labels=[1,0])
print("confusion matrix:")
print("TP FP")
print(" FN TN")
cm
# Out:
# confusion matrix:
# TP FP
#  FN TN
# array([[18, 16],
#        [24, 26]])

# %%
precision = precision_score(y_test,y_pred,zero_division=0)
print(precision)
# Out:
# 0.42857142857142855

# %%
recall=recall_score(y_test,y_pred,zero_division=0)
print(recall)
# Out:
# 0.5294117647058824

# %%
f1=f1_score(y_test,y_pred,zero_division=0)
print(f1)
#
# Out:
# 0.47368421052631576

# %%
import matplotlib.pyplot as plt
import seaborn as sns
cm=confusion_matrix(y_test,y_pred,labels=[1,0])
plt.figure(figsize=(8,6))
sns.heatmap(cm,annot=True,fmt='d',cmap='Reds',xticklabels=['Male','Female'],yticklabels=['Male','Female'])
plt.xlabel('Predicted Gender')
plt.ylabel('Actual Gender')
plt.title('Confusion Matrix')
plt.show()
#

# %%
svm_linear = SVC(kernel='rbf', class_weight='balanced',C=0.01)

svm_linear.fit(x_train, y_train)
# Out:
# SVC(C=0.01, class_weight='balanced')

# %%
y_pred=svm_linear.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,precision_score,recall_score,f1_score

# %%
accuracy = accuracy_score(y_test, y_pred)
accuracy
# Out:
# 0.40476190476190477

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred,labels=[1,0])
print("confusion matrix:")
print("TP FP")
print(" FN TN")
cm
# Out:
# confusion matrix:
# TP FP
#  FN TN
# array([[34,  0],
#        [50,  0]])

# %%
precision = precision_score(y_test,y_pred,zero_division=0)
print(precision)
# Out:
# 0.40476190476190477

# %%
recall=recall_score(y_test,y_pred,zero_division=0)
print(recall)
# Out:
# 1.0

# %%
f1=f1_score(y_test,y_pred,zero_division=0)
print(f1)
#
# Out:
# 0.576271186440678

# %%
import matplotlib.pyplot as plt
import seaborn as sns
cm=confusion_matrix(y_test,y_pred,labels=[1,0])
plt.figure(figsize=(8,6))
sns.heatmap(cm,annot=True,fmt='d',cmap='Reds',xticklabels=['Male','Female'],yticklabels=['Male','Female'])
plt.xlabel('Predicted Gender')
plt.ylabel('Actual Gender')
plt.title('Confusion Matrix')
plt.show()
#
